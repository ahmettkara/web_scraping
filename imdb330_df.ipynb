# %%
import pandas as pd
import numpy as np


imdb330 = pd.read_csv('D:\PycharmProjects\web_scraping\deneme_scrapy\imdblist\imdb330.csv')
imdb330_df = pd.DataFrame(imdb330)


imdb330_df.rename(columns = {"country":"Country", "date": "Date", "director": "Director", 
                                          "film": "Film", "rate": "Rate", "stars": "Stars"}, inplace=True)

imdb330_df.reindex(columns=["Film","Date","Country","Rate","Director","Stars"])


imdb330_df.sort_values(by="Rate", ascending=False, inplace=True)
imdb330_df.set_index(np.arange(1,(len(imdb330_df))+1), inplace=True)


imdb330_df
# Out:
#          Country               Date              Director  \
# 1            USA   14 October 1994         Frank Darabont
# 2            USA     24 March 1972   Francis Ford Coppola
# 3            USA      18 July 2008      Christopher Nolan
# 4            USA  18 December 1974   Francis Ford Coppola
# 5    Netherlands   1 December 2016           Alper Caglar
# ..           ...                ...                   ...
# 314       Turkey  26 December 2015           Furkan Kopuz
# 315          USA  17 December 2014          Peter Jackson
# 316          USA       24 May 2002      Christopher Nolan
# 317          USA     25 April 2012            Faruk Aksoy
# 318       Turkey       19 May 2013           Furkan Kopuz
#
#                                           Film  Rate  \
# 1                     The Shawshank Redemption   9.3
# 2                                The Godfather   9.2
# 3                              The Dark Knight   9.0
# ...
